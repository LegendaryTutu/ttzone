# %%
#导入包
import numpy as np
import pandas as pd
import matplotlib as plt
import statsmodels.formula.api as smf
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#使用pandas读取数据支持xls和xlsx
data=pd.read_excel("C:\\Users\\有福有德\\Desktop\\上海统计分析python20191216\\data\\bankloan_binning.xlsx")
data.head(6)
# Out:
#    ID  age  age_group  ed  employ  address  income  debtinc  creddebt  \
# 0   1   41          3   3      17       12    35.9    11.90  0.504108
# 1   2   30          2   1      13        8    46.7    17.88  1.352694
# 2   3   40          3   1      15       14    61.8    10.64  3.438997
# 3   4   41          3   1      15       14    72.0    29.67  4.165668
# 4   5   57          4   1       7       37    25.6    15.86  1.498199
# 5   6   45          4   1       0       13    28.1     4.28  0.924861
#
#      othdebt  default
# 0   3.767992        0
# 1   6.997266        0
# 2   3.136523        0
# 3  17.196732        0
# 4   2.561961        0
# 5   0.277819        0

# %%
from sklearn.metrics import confusion_matrix

#工具变量法:
# 1.误分类成本解析
X=data.iloc[:,7:10]
y=data.iloc[:,10]
fit=linear_model.LogisticRegression(solver="lbfgs").fit(X,y)
sns.heatmap(confusion_matrix(y,fit.predict(X)),fmt=".6g",annot=True)

# 2.工具变量的标识作用
fit=linear_model.LogisticRegression(solver="lbfgs").fit(X,y)
p=pd.DataFrame(fit.predict_proba(X))
data[["pred_value0","pred_value1"]]=p
data["工具"]=np.where((data1["default"]==1)&(data1["pred_value1"]<0.5),1,0)
data.head(10)

#3.测试工具是否大幅改善模型

# 4.工具变量合并bigdata上
# concat：工具为右数据集，bigdata为左数据集，执行左连接。

# 5.工具与所有变量的相关:0.8和0.9的建议，获得x
# corr

# 6.将x合并到smalldata上
#concat：x为右数据集，smalldata为左数据集，执行左连接。

# 7.构建最终模型：将x加入到最终模型
# LogisticRegression
# Out:
#    ID  age  age_group  ed  employ  address  income  debtinc  creddebt  \
# 0   1   41          3   3      17       12    35.9    11.90  0.504108
# 1   2   30          2   1      13        8    46.7    17.88  1.352694
# 2   3   40          3   1      15       14    61.8    10.64  3.438997
# 3   4   41          3   1      15       14    72.0    29.67  4.165668
# 4   5   57          4   1       7       37    25.6    15.86  1.498199
# 5   6   45          4   1       0       13    28.1     4.28  0.924861
# 6   7   36          3   1       1        3    19.6    12.82  1.211131
# 7   8   39          3   1      20        9    80.5    12.32  1.854591
# 8   9   43          3   1      12       11    68.7     6.82  1.429029
# 9  10   34          2   3       7       12    33.8    10.71  1.422652
#
#      othdebt  default  pred_value0  pred_value1  工具
# 0   3.767992        0     0.773961     0.226039   0
# 1   6.997266        0     0.637501     0.362499   0
# 2   3.136523        0     0.704734     0.295266   0
# 3  17.196732        0     0.349650     0.650350   0
# 4   2.561961        0     0.609672     0.390328   0
# 5   0.277819        0     0.868432     0.131568   0
# 6   1.301589        1     0.688348     0.311652   1
# 7   8.063009        0     0.787058     0.212942   0
# 8   3.256311        0     0.847130     0.152870   0
# 9   2.197328        0     0.752323     0.247677   0

# %%
#哑变量
data2 = pd.get_dummies(data,columns=["ed"],drop_first=False)
data2.head(10)

# x=pd.DataFrame(data2.iloc[:,[7,8,13,14,15,16]])#任意删除，如17即ed_4做参考项
# y=pd.DataFrame(data2.iloc[:,9])
# fit=linear_model.LogisticRegression().fit(x,y)
# (np.exp(fit.coef_)-1)/1*100#(or-1)/1*100%
# Out:
#    ID  age  age_group  employ  address  income  debtinc  creddebt    othdebt  \
# 0   1   41          3      17       12    35.9    11.90  0.504108   3.767992
# 1   2   30          2      13        8    46.7    17.88  1.352694   6.997266
# 2   3   40          3      15       14    61.8    10.64  3.438997   3.136523
# 3   4   41          3      15       14    72.0    29.67  4.165668  17.196732
# 4   5   57          4       7       37    25.6    15.86  1.498199   2.561961
# 5   6   45          4       0       13    28.1     4.28  0.924861   0.277819
# 6   7   36          3       1        3    19.6    12.82  1.211131   1.301589
# 7   8   39          3      20        9    80.5    12.32  1.854591   8.063009
# 8   9   43          3      12       11    68.7     6.82  1.429029   3.256311
# 9  10   34          2       7       12    33.8    10.71  1.422652   2.197328
#
#    default  pred_value0  pred_value1  工具  ed_1  ed_2  ed_3  ed_4  ed_5
# 0        0     0.773961     0.226039   0     0     0     1     0     0
# 1        0     0.637501     0.362499   0     1     0     0     0     0
# 2        0     0.704734     0.295266   0     1     0     0     0     0
# 3        0     0.349650     0.650350   0     1     0     0     0     0
# 4        0     0.609672     0.390328   0     1     0     0     0     0
# 5        0     0.868432     0.131568   0     1     0     0     0     0
# 6        1     0.688348     0.311652   1     1     0     0     0     0
# 7        0     0.787058     0.212942   0     1     0     0     0     0
# 8        0     0.847130     0.152870   0     1     0     0     0     0
# 9        0     0.752323     0.247677   0     0     0     1     0     0

# %%
#安装pip install woe
import woe.feature_process as fp
import woe.eval as el
